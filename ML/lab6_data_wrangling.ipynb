# %% [markdown]
# # inizializa

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

# metadata
print(heart_disease.metadata)

# variable information
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://archive.ics.uci.edu/static/public/45/data.csv')
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   1       145   233    1        2      150      0      2.3
# 1    67    1   4       160   286    0        2      108      1      1.5
# 2    67    1   4       120   229    0        2      129      1      2.6
# 3    37    1   3       130   250    0        0      187      0      3.5
# 4    41    0   2       130   204    0        2      172      0      1.4
# 5    56    1   2       120   236    0        0      178      0      0.8
# 6    62    0   4       140   268    0        2      160      0      3.6
# 7    57    0   4       120   354    0        0      163      1      0.6
# 8    63    1   4       130   254    0        2      147      0      1.4
# 9    53    1   4       140   203    1        2      155      1      3.1
# 10   57    1   4       140   192    0        0      148      0      0.4
# 11   56    0   2       140   294    0        2      153      0      1.3
# ...

# %% [markdown]
# # Encoding

# %% [markdown]
# ## discretizazione

# %% [markdown]
# Rendere piu discreto le eta in modo da riminuire il range di ita in fasi di vita comunemente acettate

# %%
"""
child = 0-15
teen = 15-20
adult = 20-40
middle_aged = 40-65
senior = 65+
"""

df["age_range"] = pd.cut(df["age"], bins=[0, 15, 20, 40, 65, float("inf")], labels=["child", "teen", "adult", "middle_aged", "senior"])
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num    age_range
# 0  0.0   6.0    0  middle_aged
# 1  3.0   3.0    2       senior
# 2  2.0   7.0    1       senior
# 3  0.0   3.0    0        adult
# 4  0.0   3.0    0  middle_aged

# %% [markdown]
# ## One-hot encoding

# %%
df_hot_one_encoding = pd.get_dummies(df, columns = ["sex"])
df_hot_one_encoding.head()
# Out:
#    age  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope   ca  \
# 0   63   1       145   233    1        2      150      0      2.3      3  0.0
# 1   67   4       160   286    0        2      108      1      1.5      2  3.0
# 2   67   4       120   229    0        2      129      1      2.6      2  2.0
# 3   37   3       130   250    0        0      187      0      3.5      3  0.0
# 4   41   2       130   204    0        2      172      0      1.4      1  0.0
#
#    thal  num    age_range  sex_0  sex_1
# 0   6.0    0  middle_aged  False   True
# 1   3.0    2       senior  False   True
# 2   7.0    1       senior  False   True
# 3   3.0    0        adult  False   True
# 4   3.0    0  middle_aged   True  False

# %%
df_hot_one_encoding_2 = pd.get_dummies(df, columns = ["age_range"], prefix="", prefix_sep="")
df_hot_one_encoding_2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num  child   teen  adult  middle_aged  senior
# 0  0.0   6.0    0  False  False  False         True   False
# 1  3.0   3.0    2  False  False  False        False    True
# 2  2.0   7.0    1  False  False  False        False    True
# 3  0.0   3.0    0  False  False   True        False   False
# 4  0.0   3.0    0  False  False  False         True   False

# %% [markdown]
# ## Lable encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lable_encoder = LabelEncoder()
df_label_encoding = df.copy()
df_label_encoding["age_lable"] = lable_encoder.fit_transform(df["age_range"])
df_label_encoding.head(50)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   1       145   233    1        2      150      0      2.3
# 1    67    1   4       160   286    0        2      108      1      1.5
# 2    67    1   4       120   229    0        2      129      1      2.6
# 3    37    1   3       130   250    0        0      187      0      3.5
# 4    41    0   2       130   204    0        2      172      0      1.4
# 5    56    1   2       120   236    0        0      178      0      0.8
# 6    62    0   4       140   268    0        2      160      0      3.6
# 7    57    0   4       120   354    0        0      163      1      0.6
# 8    63    1   4       130   254    0        2      147      0      1.4
# 9    53    1   4       140   203    1        2      155      1      3.1
# 10   57    1   4       140   192    0        0      148      0      0.4
# 11   56    0   2       140   294    0        2      153      0      1.3
# ...

# %% [markdown]
# ## Binary encoding

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import category_encoders as ce

# %%
df_dinary_encoding = df.copy()
binary_encoder = ce.BinaryEncoder()
df_dinary_encoding = binary_encoder.fit_transform(df_dinary_encoding)
df_dinary_encoding.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num  age_range_0  age_range_1
# 0  0.0   6.0    0            1            0
# 1  3.0   3.0    2            1            1
# 2  2.0   7.0    1            1            1
# 3  0.0   3.0    0            0            1
# 4  0.0   3.0    0            1            0

# %% [markdown]
# ## Target encoding

# %%
df_target_encoding = df.copy()
means = df_target_encoding.groupby("age_range")["chol"].mean()
df_target_encoding["category_encoded"] = df_target_encoding["age_range"].map(means)
df_target_encoding.head()
# Out:
# <ipython-input-15-2fd3f14765b8>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   means = df_target_encoding.groupby("age_range")["chol"].mean()
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num    age_range  category_encoded
# 0  0.0   6.0    0  middle_aged        247.615079
# 1  3.0   3.0    2       senior        256.939394
# ...

# %% [markdown]
# ## Frequency encoding

# %%
df_frequency_encoding = df.copy()
freq = df_frequency_encoding['age_range'].value_counts(normalize = True)*100
df_frequency_encoding["frequency"] = df_frequency_encoding["age_range"].map(freq).round(2)
df_frequency_encoding.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num    age_range  frequency
# 0  0.0   6.0    0  middle_aged      83.17
# 1  3.0   3.0    2       senior      10.89
# 2  2.0   7.0    1       senior      10.89
# 3  0.0   3.0    0        adult       5.94
# 4  0.0   3.0    0  middle_aged      83.17

# %% [markdown]
# # Normalizazione

# %% [markdown]
# ## Distribuzioni

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num    age_range
# 0  0.0   6.0    0  middle_aged
# 1  3.0   3.0    2       senior
# 2  2.0   7.0    1       senior
# 3  0.0   3.0    0        adult
# 4  0.0   3.0    0  middle_aged

# %%
numeric_colums = df.select_dtypes(include=np.number).columns.tolist()
numeric_colums
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'num']

# %%
for i in numeric_colums:
    plt.figure(figsize=(8, 6))  # Create new figure for each plot
    sns.histplot(df[i])
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# ## Min-Max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_min_max = df.copy()
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(min_max_scaler.fit_transform(df_min_max[numeric_colums]), columns = numeric_colums)

# %%
for i in numeric_colums:
    plt.figure(figsize=(8, 6))  # Create new figure for each plot
    sns.histplot(df_min_max[i])
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# ## Robus scaling

# %%
from sklearn.preprocessing import RobustScaler

# %%
robus_scaler = RobustScaler()
df_robus_scaler = pd.DataFrame(robus_scaler.fit_transform(df[numeric_colums]), columns = numeric_colums)
df_robus_scaler.head()
# Out:
#         age  sex   cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.538462  0.0 -2.0      0.75 -0.125000  1.0      0.5 -0.092308    0.0
# 1  0.846154  0.0  1.0      1.50  0.703125  0.0      0.5 -1.384615    1.0
# 2  0.846154  0.0  1.0     -0.50 -0.187500  0.0      0.5 -0.738462    1.0
# 3 -1.461538  0.0  0.0      0.00  0.140625  0.0     -0.5  1.046154    0.0
# 4 -1.153846 -1.0 -1.0      0.00 -0.578125  0.0      0.5  0.584615    0.0
#
#    oldpeak  slope   ca  thal  num
# 0   0.9375    1.0  0.0  0.75  0.0
# 1   0.4375    0.0  3.0  0.00  1.0
# 2   1.1250    0.0  2.0  1.00  0.5
# 3   1.6875    1.0  0.0  0.00  0.0
# 4   0.3750   -1.0  0.0  0.00  0.0

# %%
for i in numeric_colums:
    plt.figure(figsize=(8, 6))  # Create new figure for each plot
    sns.histplot(df_robus_scaler[i])
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# ## L1/L2 Normalization

# %%
from sklearn.preprocessing import Normalizer

# %%
df_nor = df[numeric_colums].dropna()

# %% [markdown]
# ### L2

# %%
normalizerl2 = Normalizer()
df_normalizerl2 = pd.DataFrame(normalizerl2.fit_transform(df_nor[numeric_colums]), columns = numeric_colums)
df_normalizerl2.head()
# Out:
#         age       sex        cp  trestbps      chol       fbs   restecg  \
# 0  0.197415  0.003134  0.003134  0.454368  0.730123  0.003134  0.006267
# 1  0.190575  0.002844  0.011378  0.455105  0.813501  0.000000  0.005689
# 2  0.225783  0.003370  0.013480  0.404387  0.771706  0.000000  0.006740
# 3  0.108740  0.002939  0.008817  0.382058  0.734728  0.000000  0.000000
# 4  0.136818  0.000000  0.006674  0.433813  0.680753  0.000000  0.006674
#
#     thalach     exang   oldpeak     slope        ca      thal       num
# 0  0.470036  0.000000  0.007207  0.009401  0.000000  0.018801  0.000000
# 1  0.307196  0.002844  0.004267  0.005689  0.008533  0.008533  0.005689
# 2  0.434716  0.003370  0.008762  0.006740  0.006740  0.023589  0.003370
# 3  0.549576  0.000000  0.010286  0.008817  0.000000  0.008817  0.000000
# 4  0.573968  0.000000  0.004672  0.003337  0.000000  0.010011  0.000000

# %%
for i in numeric_colums:
    plt.figure(figsize=(8, 6))  # Create new figure for each plot
    sns.histplot(df_normalizerl2[i])
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# ### L1

# %%
normalizerl1 = Normalizer(norm = "l1")
df_normalizerl1 = pd.DataFrame(normalizerl1.fit_transform(df_nor[numeric_colums]), columns = numeric_colums)
df_normalizerl1.head()
# Out:
#         age       sex        cp  trestbps      chol       fbs   restecg  \
# 0  0.103738  0.001647  0.001647  0.238762  0.383665  0.001647  0.003293
# 1  0.104606  0.001561  0.006245  0.249805  0.446526  0.000000  0.003123
# 2  0.118041  0.001762  0.007047  0.211416  0.403453  0.000000  0.003524
# 3  0.059919  0.001619  0.004858  0.210526  0.404858  0.000000  0.000000
# 4  0.073688  0.000000  0.003595  0.233645  0.366643  0.000000  0.003595
#
#     thalach     exang   oldpeak     slope        ca      thal       num
# 0  0.246995  0.000000  0.003787  0.004940  0.000000  0.009880  0.000000
# 1  0.168618  0.001561  0.002342  0.003123  0.004684  0.004684  0.003123
# 2  0.227273  0.001762  0.004581  0.003524  0.003524  0.012333  0.001762
# 3  0.302834  0.000000  0.005668  0.004858  0.000000  0.004858  0.000000
# 4  0.309130  0.000000  0.002516  0.001797  0.000000  0.005392  0.000000

# %%
for i in numeric_colums:
    plt.figure(figsize=(8, 6))  # Create new figure for each plot
    sns.histplot(df_normalizerl1[i])
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.show()
